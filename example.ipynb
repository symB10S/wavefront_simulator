# %%
import wavefronts.generation as gen
import wavefronts.plotting as wp
import wavefronts.interactive as wi
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
interface = gen.generate_interface_data(L_time='0.003',C_time='0.0005',show_about=False)

# %%
fix, ax = plt.subplots()

wp.plot_fanout_magnitude(interface.data_output_commutative.Current_Interconnect_Capacitor,ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wi.interact_3D_spatial(interface)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', layout=Layout(width='auto'), max=1000.0, step=1.…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wi.interact_spatial(interface)
# Out:
# GridspecLayout(children=(Button(description='step backward', layout=Layout(grid_area='widget001', width='auto'…
# FloatSlider(value=0.0, layout=Layout(width='auto'), max=1000.0, step=1.0, tooltip='enter number from 0 to 1000…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wi.interact_fanout_path(interface)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', layout=Layout(width='auto'), max=1000.0, step=1.…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# wp.save_spatial_interconnect(interface,save_name = 'test')
# Out:
# 100%|██████████| 1800/1800 [15:14<00:00,  1.97it/s]
# Spatial video generation completed, video saved as test.mp4
